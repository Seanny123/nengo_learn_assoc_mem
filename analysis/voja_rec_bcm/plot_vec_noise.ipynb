# %%
import os

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from nengo_learn_assoc_mem.paths import data_path

# %matplotlib inline

# %%
df = pd.read_hdf(os.path.join(data_path, "neg_voja_rec_test", "test_all.h5"), "conf", mode="r")

# %%
sns.barplot(x="rec_w", y="rn_dist", hue="noise_mag", data=df[(df.rec_syn == 0.0) | (df.rec_syn == 0.005)])

# %%
sns.barplot(x="rec_w", y="mag", hue="noise_mag", data=df[(df.rec_syn == 0.0) | (df.rec_syn == 0.005)])

# %%
sns.barplot(x="rec_syn", y="rn_dist", hue="noise_mag", data=df)

# %%
sns.barplot(x="rec_syn", y="mag", hue="noise_mag", data=df)
